# %%
import gen_latest_predictions
# Out:
# /usr/local/envs/py3env/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Trying fix_yahoo_finance...
#
# ...
#
# [*********************100%***********************]  179 of 179 downloaded
#
# creating normalised windows for OCN (1/1)
# iteration: 1 of 6
# /content/datalab/basemap/lstm_model.py:29: UserWarning: The `input_dim` and `input_length` arguments in recurrent layers are deprecated. Use `input_shape` instead.
#   return_sequences=True))
# /content/datalab/basemap/lstm_model.py:29: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(units=42, return_sequences=True, input_shape=(None, 5))`
#   return_sequences=True))
# ...
